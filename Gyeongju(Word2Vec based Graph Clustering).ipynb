# %%
import import_ipynb

import pandas as pd
import numpy as np
from tqdm import tqdm
# %matplotlib inline

from eunjeon import Mecab; mecab = Mecab()
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec

# 맷플롯립 그래프 한글폰트깨짐 방지
import matplotlib as mpl
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

# 데이터프레임 출력시 잘림현상 해결
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# 경고 제거
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 사용되는 함수 목록

# %%
# 데이터프레임에서 명사만 추출, 한글자 단어 제거, 불용어 제거하는 함수
def text_process(contents):
    # 불용어 목록 가져오기
    file = open('./dataset/stopwords.txt', 'r', encoding='UTF8')
    STOPWORDS = file.read().split(', ')
    file.close()
    
    # 30회 초과 단어목록 가져오기
    file = open('./dataset/gyeongju/min30.txt', 'r', encoding='utf-8')
    MINWORDS = file.read().split(',')
    file.close()
    
    # Dataframe title, content를 리스트로 변환
    content_list = [content for content in contents]
    
    # 리스트 -> 문자열로 변환
    content_text = ''.join(content_list)
    
    # 형태소분석 -> 명사만 추출
    noun_list = mecab.nouns(content_text)
    
    # 한글자 단어 제거
    noun_list = [x for x in noun_list if len(x)>=2]
    
    # 경주시->경주 통합
    for i in range(len(noun_list)):
        if(noun_list[i]=='경주시'):
            noun_list[i] = '경주'   
        
    # 30회 초과 단어만 채택
    noun_list = [word for word in noun_list if word in MINWORDS]
        
    # 불용어 제거 후 반환
    return ' '.join([word for word in noun_list if word not in STOPWORDS])

# %%
# TF-IDF를 통해 문서의 핵심어를 랭킹순으로 추출 -> 리스트로 반환
def getRankListFromSeries(s):
    clean_list = s.to_list()

    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(clean_list)

    terms = tfidf_vectorizer.get_feature_names()

    # TF-IDF 각 단어의 결과를 더함
    sums = tfidf_matrix.sum(axis=0)

    # 단어와 결과를 연결
    data = []
    for idx, term in enumerate(terms):
           data.append( (term, sums[0, idx] ))

    # 데이터프레임으로 변환, 내림차순 정렬 
    ranking_df = pd.DataFrame(data, columns=['term','rank'])
    ranking_df.sort_values('rank',inplace=True, ascending=False)
    
    # 리스트로 반환
    return tolist(ranking_df)

# %%
# 데이터프레임 -> 리스트로 변환
def tolist(df):
    return [tuple(r) for r in df.to_numpy()]

# %% [markdown]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ### 판다스로 네이버블로그 데이터셋 불러오기

# %%
data_df = pd.read_excel("./dataset/gyeongju/naverview_gyeongju.xlsx", engine="openpyxl")
data_df.head()
# Out:
#                        title               nickname            datetime  \
# 0     경주맛집 - 참가자미회가 맛있는 양지식당       머시블루\n(mercyblu)  2010. 11. 1. 11:19
# 1     동화 같던 경주 스위트 메종 호텔 산책로         하나\n(louismom)  2010. 12. 1. 12:10
# 2  경주 남산 불곡 석불좌상 [경주여행/경주남산]  까칠한포에버쥔장\n(papalagi2)  2010. 10. 16. 9:06
# 3   경주 맛집 - 숙영식당 (찰보리밥 + 파전)       윈드보이\n(wind3202)   2010. 5. 14. 0:00
# 4           나홀로 경주 스쿠터여행 [1]         옐로산도\n(kiyunm)   2010. 5. 6. 19:54
#
#                                              content
# 0  경주하면 도시 전체가 유적지여서 차분히 볼거리가 많고 번잡하지 않고\n고즈넉하여 돌...
# 1    한적하고 평화로운 경주의 산책로는 아직 끝나지 않았다.\n어쩜 이렇게 좋을까.\...
# 2   1963년 1월 21일 보물 제198호로 지정되었다.\n이 불상은 경주남산 동쪽 ...
# 3  경주에서 마지막 식사를 한곳 숙영식당..\n원래는 매운탕집을 갈 예정이었으나, 황남...
# 4  연차를 내고.. 나 홀로 떠난 1박2일의 경주여행.\n그 흔한 수학여행으로도 가본적...

# %% [markdown]
# ### 데이터프레임의 title, content를 클렌징후 clean_title, clean_content 칼럼에 저장

# %%
data_df['title'] = data_df['title'].astype('str')
data_df['content'] = data_df['content'].astype('str')

# %%
data_df['clean_title'] = data_df.title.apply(text_process)
data_df['clean_content'] = data_df['clean_title'] + " " + data_df.content.apply(text_process)

# %%
data_df.head()
# Out:
#                        title               nickname            datetime  \
# 0     경주맛집 - 참가자미회가 맛있는 양지식당       머시블루\n(mercyblu)  2010. 11. 1. 11:19
# 1     동화 같던 경주 스위트 메종 호텔 산책로         하나\n(louismom)  2010. 12. 1. 12:10
# 2  경주 남산 불곡 석불좌상 [경주여행/경주남산]  까칠한포에버쥔장\n(papalagi2)  2010. 10. 16. 9:06
# 3   경주 맛집 - 숙영식당 (찰보리밥 + 파전)       윈드보이\n(wind3202)   2010. 5. 14. 0:00
# 4           나홀로 경주 스쿠터여행 [1]         옐로산도\n(kiyunm)   2010. 5. 6. 19:54
#
#                                              content  \
# 0  경주하면 도시 전체가 유적지여서 차분히 볼거리가 많고 번잡하지 않고\n고즈넉하여 돌...
# 1    한적하고 평화로운 경주의 산책로는 아직 끝나지 않았다.\n어쩜 이렇게 좋을까.\...
# 2   1963년 1월 21일 보물 제198호로 지정되었다.\n이 불상은 경주남산 동쪽 ...
# 3  경주에서 마지막 식사를 한곳 숙영식당..\n원래는 매운탕집을 갈 예정이었으나, 황남...
# 4  연차를 내고.. 나 홀로 떠난 1박2일의 경주여행.\n그 흔한 수학여행으로도 가본적...
#
#                  clean_title  \
# 0                경주 맛집 양지 식당
# 1           동화 경주 스위트 호텔 산책로
# 2  경주 남산 불곡 석불좌상 경주 여행 경주 남산
# 3         경주 맛집 숙영 식당 찰보리 파전
# 4                  경주 스쿠터 여행
#
#                                        clean_content
# 0  경주 맛집 양지 식당 경주 도시 전체 유적지 거리 먹거리 경주 나들이 신경 친구 센...
# 1  동화 경주 스위트 호텔 산책로 평화 경주 산책로 다람쥐 가을 양식 박물관 풍경 사람...
# 2  경주 남산 불곡 석불좌상 경주 여행 경주 남산 보물 지정 불상 경주 남산 동쪽 기슭...
# 3  경주 맛집 숙영 식당 찰보리 파전 경주 식사 숙영 식당 매운탕 예정 황남빵 경주 기...
# 4  경주 스쿠터 여행 경주 여행 수학여행 가본 자전거 여행 자전거 고생 경주 기억 스쿠...

# %% [markdown]
# ### Word2Vec를 이용해 단어-벡터 생성

# %%
# 명사 목록 가져오기
content_noun_list = []

for i in range(len(data_df)):
    content_noun_list.append(data_df['clean_content'][i])

# string형으로 변환
content_str = ' '.join([word for word in content_noun_list]).split()

# %%
# 학습
model = Word2Vec([content_str], vector_size=300, window=10, min_count=1, workers=4, sg=1, epochs=20)

# %%
word_list = [word[0] for word in getRankListFromSeries(data_df['clean_content'])[:100]] #tf-idf

# %%
# 단어와 벡터값 연결
my_dict = dict({})

for idx, key in enumerate(word_list):
    my_dict[key] = model.wv[key]

# %%
# 데이터프레임으로 만들기
wordvectors_df = pd.DataFrame(my_dict).transpose()
wordvectors_df.head()
# Out:
#            0         1         2         3         4         5         6    \
# 공주시  -0.137330  0.076077  0.381796  0.184333 -0.175160  0.065373  0.315383
# 충청남도 -0.309300  0.349360  0.435065 -0.004743 -0.128152  0.100432  0.411326
# 사업    0.056516 -0.021268  0.223372  0.070126 -0.048164  0.137608  0.491830
# 문화   -0.272482 -0.044505  0.245622  0.047507 -0.131650  0.030578  0.053810
# 시민   -0.329223  0.299743  0.479222  0.279194 -0.043488  0.091006  0.034707
#
#            7         8         9         10        11        12        13   \
# 공주시   0.265689 -0.083797  0.116345 -0.056779 -0.026396 -0.028523  0.187856
# 충청남도  0.379653 -0.015293  0.242914  0.129562 -0.158200  0.053940  0.090262
# 사업    0.190630  0.247968  0.054296  0.153831 -0.114522  0.013678  0.373018
# 문화    0.219450  0.112141 -0.151959 -0.068748 -0.018107  0.061301  0.226032
# 시민    0.365743 -0.163318  0.020311 -0.065667 -0.266164  0.113336  0.345726
#
#            14        15        16        17        18        19        20   \
# 공주시  -0.265367 -0.032766  0.093391 -0.253150 -0.195932 -0.081355  0.031661
# 충청남도  0.018111 -0.186604  0.121507 -0.287826 -0.205629  0.190597  0.057905
# 사업   -0.152437  0.031921  0.124291 -0.200486  0.151777 -0.366434 -0.002712
# 문화    0.037766 -0.289812  0.081430 -0.421757  0.136170 -0.144570  0.134593
# 시민    0.123778 -0.100988 -0.207671 -0.384725 -0.101552  0.051021  0.070282
#
#            21        22        23        24        25        26        27   \
# 공주시   0.002786  0.003025 -0.058508  0.501730 -0.112646  0.063525  0.246145
# 충청남도 -0.025103 -0.027865  0.245761  0.186747 -0.050123 -0.049343  0.065122
# 사업   -0.002158  0.077410  0.021370  0.357677 -0.196761  0.158397  0.188705
# 문화   -0.086790  0.086046 -0.008438  0.199039 -0.099996  0.014587  0.356043
# 시민    0.040876  0.065582 -0.060129  0.163497  0.024899 -0.040951  0.271063
#
#            28        29        30        31        32        33        34   \
# 공주시  -0.247625 -0.234531 -0.183843  0.103966  0.170432 -0.049347 -0.243495
# 충청남도 -0.110603 -0.263797 -0.112389  0.103257 -0.089269 -0.015659 -0.393242
# 사업   -0.204873 -0.246290  0.229079 -0.085431  0.119342  0.159425 -0.218266
# 문화   -0.092320 -0.078898 -0.063145 -0.038214  0.191821  0.155350 -0.060842
# 시민   -0.066205 -0.134793 -0.398427  0.197685  0.181368  0.195924 -0.208893
#
#            35        36        37        38        39        40        41   \
# 공주시   0.025616  0.252890 -0.206117 -0.139029 -0.156985 -0.466729  0.112383
# 충청남도 -0.110863  0.341815 -0.112049 -0.009585  0.039142 -0.369242  0.067646
# 사업   -0.163345  0.014095 -0.611778 -0.286003 -0.177085 -0.343722  0.118279
# 문화    0.010589  0.181915 -0.165406 -0.213386 -0.105511 -0.177459 -0.013246
# 시민    0.225078  0.205183 -0.357539 -0.032663  0.227601 -0.240214 -0.159563
#
#            42        43        44        45        46        47        48   \
# 공주시  -0.080603 -0.192894 -0.058236 -0.117419 -0.049229  0.220709  0.139944
# 충청남도 -0.147863 -0.204602 -0.158733 -0.204609 -0.026289  0.370984  0.186673
# 사업   -0.111807 -0.212745  0.164884  0.047973  0.174231  0.041788  0.033516
# 문화   -0.265058  0.028563 -0.060547 -0.052366  0.106838  0.330246  0.026799
# 시민   -0.247657 -0.065784 -0.159057  0.038060  0.047346  0.314376 -0.015281
#
#            49   ...       250       251       252       253       254  \
# 공주시   0.316882  ...  0.032835  0.047377 -0.057088 -0.144648 -0.101045
# 충청남도  0.146326  ...  0.129054  0.131347 -0.014219 -0.029655 -0.028212
# 사업    0.152677  ... -0.100798  0.218397  0.193671 -0.162308 -0.305666
# 문화    0.198300  ... -0.113366  0.109098  0.276508 -0.100151 -0.106755
# 시민    0.165849  ... -0.023838  0.223049  0.114319 -0.112571  0.076102
#
#            255       256       257       258       259       260       261  \
# 공주시  -0.216251  0.088783 -0.001995 -0.306306 -0.009064 -0.021173  0.193775
# 충청남도 -0.262344  0.129274 -0.009859 -0.349759  0.071539  0.075842  0.172446
# 사업   -0.088369  0.352108  0.288166 -0.456475 -0.061586 -0.129436 -0.040631
# 문화   -0.205899  0.172925  0.173692 -0.309801  0.076138  0.091965  0.323507
# 시민   -0.450406 -0.056285  0.180013 -0.382527 -0.077353 -0.001320  0.253448
#
#            262       263       264       265       266       267       268  \
# 공주시   0.101151 -0.052101 -0.127866  0.017157  0.155811  0.126036 -0.415746
# 충청남도  0.047730 -0.044450 -0.061812 -0.001376  0.051091  0.237680 -0.358477
# 사업    0.266833 -0.263569 -0.306589 -0.199048  0.270621  0.114990 -0.399727
# 문화    0.332527 -0.028951 -0.285074 -0.370701  0.100976  0.008016 -0.505603
# 시민    0.353316 -0.043414 -0.086269 -0.016056  0.122907  0.442555 -0.434998
#
#            269       270       271       272       273       274       275  \
# 공주시  -0.101039  0.195891  0.050764  0.330882 -0.089398  0.031096 -0.191544
# 충청남도 -0.089843  0.192061  0.071331  0.206530  0.095900  0.090799  0.053586
# 사업    0.009177 -0.100224 -0.106814  0.534395 -0.140826  0.040456 -0.252400
# 문화   -0.407400  0.045243 -0.007690  0.212819 -0.052240  0.053764 -0.019580
# 시민   -0.390625  0.105556 -0.194582  0.077847  0.085827  0.078642 -0.005396
#
#            276       277       278       279       280       281       282  \
# 공주시   0.310311 -0.125307 -0.323905 -0.225931  0.140536 -0.157318 -0.196106
# 충청남도  0.292131 -0.006040 -0.459130 -0.335373  0.117449 -0.070893 -0.233503
# 사업    0.225374 -0.448133 -0.421539 -0.268365  0.091548  0.083081 -0.324523
# 문화    0.288820 -0.114906 -0.290916 -0.402428 -0.049802  0.333986 -0.236630
# 시민    0.419564 -0.131606 -0.231067 -0.031058 -0.119174  0.158083 -0.084110
#
#            283       284       285       286       287       288       289  \
# 공주시   0.131729  0.089489 -0.076792 -0.125637 -0.138003 -0.046680  0.125453
# 충청남도 -0.073157  0.112341 -0.009880 -0.167937  0.012696  0.050330  0.017992
# 사업    0.088178  0.263927 -0.219519 -0.092577 -0.146193  0.084443  0.117693
# 문화   -0.205794  0.077883 -0.073197 -0.174691 -0.198185  0.315040 -0.027642
# 시민    0.003478  0.295628  0.123931 -0.099816 -0.081630  0.149694 -0.013966
#
#            290       291       292       293       294       295       296  \
# 공주시  -0.107291  0.237199  0.329025 -0.060806  0.025870  0.113530  0.098334
# 충청남도 -0.018198  0.228030  0.193789 -0.022138  0.129027  0.055223  0.179445
# 사업   -0.120990  0.327958  0.289991  0.022747  0.323319  0.270263  0.043523
# 문화    0.167272  0.201318  0.347425  0.037359  0.165598  0.311950  0.026952
# 시민    0.015884  0.359941  0.381899 -0.209752  0.252317  0.156055  0.326948
#
#            297       298       299
# 공주시   0.035423  0.298585 -0.032412
# 충청남도 -0.158805  0.375283 -0.159981
# 사업    0.255255  0.494759 -0.150806
# 문화    0.160745  0.392433  0.065420
# 시민    0.092946  0.537969  0.018923
#
# [5 rows x 300 columns]

# %% [markdown]
# ### 단어간 코사인 유사도 계산

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b)))

# %%
count_dict = {}

for i in tqdm(range(len(wordvectors_df))):
    for j in range(i+1, len(wordvectors_df)):
        cossim = cosine_similarity(wordvectors_df.iloc[i, :].values, wordvectors_df.iloc[j, :].values)
        count_dict[wordvectors_df.iloc[i, :].name, wordvectors_df.iloc[j, :].name] = cossim
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 65.89it/s]

# %%
count_dict
# Out:
# {('공주시', '충청남도'): 0.72568923,
#  ('공주시', '사업'): 0.6959532,
#  ('공주시', '문화'): 0.61817205,
#  ('공주시', '시민'): 0.68895835,
#  ('공주시', '도시'): 0.6445625,
#  ('공주시', '체험'): 0.6020312,
#  ('공주시', '마을'): 0.5578016,
#  ('공주시', '사진'): 0.7057952,
#  ('공주시', '교육'): 0.6409314,
#  ('공주시', '백제'): 0.43627957,
#  ('공주시', '토지'): 0.6169109,
#  ('공주시', '시장'): 0.69591767,
#  ('공주시', '행사'): 0.6784736,
#  ('공주시', '행정'): 0.61403847,
#  ('공주시', '주택'): 0.5450549,
#  ('공주시', '계룡산'): 0.6495086,
#  ('공주시', '계획'): 0.6518773,
#  ('공주시', '공산'): 0.5687432,
#  ('공주시', '수도'): 0.76540416,
#  ('공주시', '카페'): 0.06696865,
#  ('공주시', '안전'): 0.5746197,
#  ('공주시', '마곡사'): 0.70273167,
#  ('공주시', '축제'): 0.61860865,
#  ('공주시', '맛집'): 0.013807876,
#  ('공주시', '대전'): 0.7147663,
#  ('공주시', '주민'): 0.5200192,
#  ('공주시', '금강'): 0.5815346,
#  ('공주시', '공원'): 0.7270296,
#  ('공주시', '활동'): 0.5957697,
#  ('공주시', '관광'): 0.5718821,
#  ('공주시', '갑사'): 0.43404773,
#  ('공주시', '박물관'): 0.50331485,
#  ('공주시', '기자'): 0.8440094,
#  ('공주시', '관리'): 0.58098483,
#  ('공주시', '복지'): 0.6252997,
#  ('공주시', '참여'): 0.61054856,
#  ('공주시', '개발'): 0.5648001,
#  ('공주시', '진행'): 0.67419994,
#  ('공주시', '이용'): 0.5659786,
#  ('공주시', '설치'): 0.6677592,
#  ('공주시', '농촌'): 0.6125963,
#  ('공주시', '공간'): 0.57065386,
#  ('공주시', '가능'): 0.57563543,
#  ('공주시', '동학사'): -0.043512862,
#  ('공주시', '방문'): 0.76665205,
#  ('공주시', '센터'): 0.66064876,
#  ('공주시', '서비스'): 0.63005286,
#  ('공주시', '대상'): 0.66113,
#  ('공주시', '조성'): 0.59739876,
#  ('공주시', '사회'): 0.62107164,
#  ('공주시', '생활'): 0.5368398,
#  ('공주시', '도로'): 0.6424441,
#  ('공주시', '봉사'): 0.68431914,
#  ('공주시', '대회'): 0.66466945,
#  ('공주시', '자연'): 0.59091735,
#  ('공주시', '사랑'): 0.6825466,
#  ('공주시', '이건용'): 0.78184825,
#  ('공주시', '역사'): 0.5475229,
#  ('공주시', '서울'): 0.6010395,
#  ('공주시', '행복'): 0.8659619,
#  ('공주시', '여행'): 0.6803581,
#  ('공주시', '건물'): 0.5273598,
#  ('공주시', '시공'): 0.073521584,
#  ('공주시', '시대'): 0.35508704,
#  ('공주시', '가격'): 0.76026565,
#  ('공주시', '농업'): 0.6823162,
#  ('공주시', '자리'): 0.52149063,
#  ('공주시', '발전'): 0.7311748,
#  ('공주시', '가족'): 0.66374606,
#  ('공주시', '지정'): 0.60789156,
#  ('공주시', '시청'): 0.76882476,
#  ('공주시', '한국'): 0.5800477,
#  ('공주시', '환경'): 0.66286737,
#  ('공주시', '사용'): 0.68909734,
#  ('공주시', '공사'): 0.59720033,
#  ('공주시', '학교'): 0.7827769,
#  ('공주시', '건강'): 0.6036299,
#  ('공주시', '자원'): 0.6453346,
#  ('공주시', '반포면'): 0.6304838,
#  ('공주시', '신관동'): 0.70454705,
#  ('공주시', '아파트'): 0.74685925,
#  ('공주시', '평가'): 0.5956394,
#  ('공주시', '인테리어'): 0.68872,
#  ('공주시', '제공'): 0.7373715,
#  ('공주시', '단체'): 0.68784773,
#  ('공주시', '예정'): 0.6995286,
#  ('공주시', '선정'): 0.6268701,
#  ('공주시', '자전거'): 0.7359307,
#  ('공주시', '공무원'): 0.698472,
#  ('공주시', '정보'): 0.60035926,
#  ('공주시', '기관'): 0.64789355,
#  ('공주시', '식당'): 0.75383055,
#  ('공주시', '지구'): 0.50033295,
#  ('공주시', '의원'): 0.6148091,
#  ('공주시', '대표'): 0.75457376,
#  ('공주시', '오후'): 0.8060945,
#  ('공주시', '건설'): 0.64600044,
#  ('공주시', '민원'): 0.79845023,
#  ('공주시', '프로그램'): 0.6982989,
#  ('충청남도', '사업'): 0.47314793,
#  ('충청남도', '문화'): 0.5236105,
#  ('충청남도', '시민'): 0.6115258,
#  ('충청남도', '도시'): 0.5885208,
#  ('충청남도', '체험'): 0.5015585,
#  ('충청남도', '마을'): 0.61622775,
#  ('충청남도', '사진'): 0.7823551,
#  ('충청남도', '교육'): 0.48305804,
#  ('충청남도', '백제'): 0.43810728,
#  ('충청남도', '토지'): 0.59896433,
#  ('충청남도', '시장'): 0.645637,
#  ('충청남도', '행사'): 0.61590594,
#  ('충청남도', '행정'): 0.5057045,
#  ('충청남도', '주택'): 0.6220053,
#  ('충청남도', '계룡산'): 0.74504375,
#  ('충청남도', '계획'): 0.66593355,
#  ('충청남도', '공산'): 0.6449829,
#  ('충청남도', '수도'): 0.81874853,
#  ('충청남도', '카페'): 0.08087526,
#  ('충청남도', '안전'): 0.58579206,
#  ('충청남도', '마곡사'): 0.7020052,
#  ('충청남도', '축제'): 0.5867803,
#  ('충청남도', '맛집'): 0.08721232,
#  ('충청남도', '대전'): 0.812655,
#  ('충청남도', '주민'): 0.49829707,
#  ('충청남도', '금강'): 0.6347689,
#  ('충청남도', '공원'): 0.7418988,
#  ('충청남도', '활동'): 0.65330243,
#  ('충청남도', '관광'): 0.5818595,
#  ('충청남도', '갑사'): 0.58429265,
#  ('충청남도', '박물관'): 0.4905954,
#  ('충청남도', '기자'): 0.59723234,
#  ('충청남도', '관리'): 0.52056926,
#  ('충청남도', '복지'): 0.5056306,
#  ('충청남도', '참여'): 0.56861675,
#  ('충청남도', '개발'): 0.588643,
#  ('충청남도', '진행'): 0.669651,
#  ('충청남도', '이용'): 0.628694,
#  ('충청남도', '설치'): 0.64358044,
#  ('충청남도', '농촌'): 0.5100408,
#  ('충청남도', '공간'): 0.5348478,
#  ('충청남도', '가능'): 0.5944003,
#  ('충청남도', '동학사'): -0.09709365,
#  ('충청남도', '방문'): 0.64834756,
#  ('충청남도', '센터'): 0.61261994,
#  ('충청남도', '서비스'): 0.47959524,
#  ('충청남도', '대상'): 0.48645693,
#  ('충청남도', '조성'): 0.5186567,
#  ('충청남도', '사회'): 0.5146171,
#  ('충청남도', '생활'): 0.38261855,
#  ('충청남도', '도로'): 0.7574672,
#  ('충청남도', '봉사'): 0.59024113,
#  ('충청남도', '대회'): 0.5077959,
#  ('충청남도', '자연'): 0.63465154,
#  ('충청남도', '사랑'): 0.67206556,
#  ('충청남도', '이건용'): 0.6854982,
#  ('충청남도', '역사'): 0.5858151,
#  ('충청남도', '서울'): 0.77377933,
#  ('충청남도', '행복'): 0.69276786,
#  ('충청남도', '여행'): 0.7876922,
#  ('충청남도', '건물'): 0.67942685,
#  ('충청남도', '시공'): 0.038165618,
#  ('충청남도', '시대'): 0.3525415,
#  ('충청남도', '가격'): 0.6266912,
#  ('충청남도', '농업'): 0.5865719,
#  ('충청남도', '자리'): 0.54420364,
#  ('충청남도', '발전'): 0.5589845,
#  ('충청남도', '가족'): 0.5921378,
#  ('충청남도', '지정'): 0.6452391,
#  ('충청남도', '시청'): 0.63354045,
#  ('충청남도', '한국'): 0.5881681,
#  ('충청남도', '환경'): 0.5334322,
#  ('충청남도', '사용'): 0.6607717,
#  ('충청남도', '공사'): 0.5552513,
#  ('충청남도', '학교'): 0.7343528,
#  ('충청남도', '건강'): 0.51214224,
#  ('충청남도', '자원'): 0.5467204,
#  ('충청남도', '반포면'): 0.5361036,
#  ('충청남도', '신관동'): 0.7740232,
#  ('충청남도', '아파트'): 0.70136917,
#  ('충청남도', '평가'): 0.5474573,
#  ('충청남도', '인테리어'): 0.6447283,
#  ('충청남도', '제공'): 0.60018796,
#  ('충청남도', '단체'): 0.5542414,
#  ('충청남도', '예정'): 0.55231154,
#  ('충청남도', '선정'): 0.4891152,
#  ('충청남도', '자전거'): 0.7815616,
#  ('충청남도', '공무원'): 0.5778568,
#  ('충청남도', '정보'): 0.41190544,
#  ('충청남도', '기관'): 0.6264056,
#  ('충청남도', '식당'): 0.7397828,
#  ('충청남도', '지구'): 0.5405115,
#  ('충청남도', '의원'): 0.71114284,
#  ('충청남도', '대표'): 0.6848686,
#  ('충청남도', '오후'): 0.5974392,
#  ('충청남도', '건설'): 0.6103834,
#  ('충청남도', '민원'): 0.74152315,
#  ('충청남도', '프로그램'): 0.6505038,
#  ('사업', '문화'): 0.6257975,
#  ('사업', '시민'): 0.5053396,
#  ('사업', '도시'): 0.6478102,
#  ('사업', '체험'): 0.6093853,
#  ('사업', '마을'): 0.36880228,
#  ('사업', '사진'): 0.41421548,
#  ('사업', '교육'): 0.6658926,
#  ('사업', '백제'): 0.42674804,
#  ('사업', '토지'): 0.7637255,
#  ('사업', '시장'): 0.6870836,
#  ('사업', '행사'): 0.53993946,
#  ('사업', '행정'): 0.5976284,
#  ('사업', '주택'): 0.63105214,
#  ('사업', '계룡산'): 0.5177354,
#  ('사업', '계획'): 0.6826597,
#  ('사업', '공산'): 0.48943242,
#  ('사업', '수도'): 0.63109154,
#  ('사업', '카페'): 0.080713965,
#  ('사업', '안전'): 0.54097885,
#  ('사업', '마곡사'): 0.54892933,
#  ('사업', '축제'): 0.5001153,
#  ('사업', '맛집'): 0.06657958,
#  ('사업', '대전'): 0.4827451,
#  ('사업', '주민'): 0.48774314,
#  ('사업', '금강'): 0.39679503,
#  ('사업', '공원'): 0.5663616,
#  ('사업', '활동'): 0.530452,
#  ('사업', '관광'): 0.6555018,
#  ('사업', '갑사'): 0.33002815,
#  ('사업', '박물관'): 0.4085704,
#  ('사업', '기자'): 0.67638344,
#  ('사업', '관리'): 0.6451192,
#  ('사업', '복지'): 0.6588732,
#  ('사업', '참여'): 0.49931288,
#  ('사업', '개발'): 0.71714747,
#  ('사업', '진행'): 0.6660279,
#  ('사업', '이용'): 0.53195816,
#  ('사업', '설치'): 0.57823896,
#  ('사업', '농촌'): 0.6250236,
#  ('사업', '공간'): 0.729563,
#  ('사업', '가능'): 0.69221497,
#  ('사업', '동학사'): 0.07250622,
#  ('사업', '방문'): 0.6616761,
#  ('사업', '센터'): 0.6260718,
#  ('사업', '서비스'): 0.676682,
#  ('사업', '대상'): 0.6589606,
#  ('사업', '조성'): 0.72513163,
#  ('사업', '사회'): 0.6138888,
#  ('사업', '생활'): 0.59923565,
#  ('사업', '도로'): 0.49720246,
#  ('사업', '봉사'): 0.5792323,
#  ('사업', '대회'): 0.5607485,
#  ('사업', '자연'): 0.56527185,
#  ('사업', '사랑'): 0.45933646,
#  ('사업', '이건용'): 0.70372504,
#  ('사업', '역사'): 0.42618468,
#  ('사업', '서울'): 0.43146604,
#  ('사업', '행복'): 0.77679634,
#  ('사업', '여행'): 0.56404597,
#  ('사업', '건물'): 0.34383333,
#  ('사업', '시공'): 0.0811615,
#  ('사업', '시대'): 0.43667662,
#  ('사업', '가격'): 0.78824896,
#  ('사업', '농업'): 0.7345856,
#  ('사업', '자리'): 0.44401088,
#  ('사업', '발전'): 0.48491895,
#  ('사업', '가족'): 0.50364494,
#  ('사업', '지정'): 0.6455613,
#  ('사업', '시청'): 0.67326075,
#  ('사업', '한국'): 0.4841862,
#  ('사업', '환경'): 0.7982989,
#  ('사업', '사용'): 0.7355003,
#  ('사업', '공사'): 0.6014874,
#  ('사업', '학교'): 0.6659895,
#  ('사업', '건강'): 0.6613406,
#  ('사업', '자원'): 0.62992275,
#  ('사업', '반포면'): 0.6923035,
#  ('사업', '신관동'): 0.5943469,
#  ('사업', '아파트'): 0.7740907,
#  ('사업', '평가'): 0.8432199,
#  ('사업', '인테리어'): 0.6640554,
#  ('사업', '제공'): 0.74139047,
#  ('사업', '단체'): 0.6691761,
#  ('사업', '예정'): 0.7199323,
#  ('사업', '선정'): 0.81921685,
#  ('사업', '자전거'): 0.67178345,
#  ('사업', '공무원'): 0.57180923,
#  ('사업', '정보'): 0.7577217,
#  ('사업', '기관'): 0.67201626,
#  ('사업', '식당'): 0.6837216,
#  ('사업', '지구'): 0.71616405,
#  ('사업', '의원'): 0.5234554,
#  ('사업', '대표'): 0.5377452,
#  ('사업', '오후'): 0.60231644,
#  ('사업', '건설'): 0.6259873,
#  ('사업', '민원'): 0.73856336,
#  ('사업', '프로그램'): 0.6974008,
#  ('문화', '시민'): 0.718223,
#  ('문화', '도시'): 0.69916254,
#  ('문화', '체험'): 0.8214266,
#  ('문화', '마을'): 0.42798492,
#  ('문화', '사진'): 0.61485016,
#  ('문화', '교육'): 0.5732913,
#  ('문화', '백제'): 0.762756,
#  ('문화', '토지'): 0.61061025,
#  ('문화', '시장'): 0.70023423,
#  ('문화', '행사'): 0.81803304,
#  ('문화', '행정'): 0.57261086,
#  ('문화', '주택'): 0.42420098,
#  ('문화', '계룡산'): 0.7217761,
#  ('문화', '계획'): 0.53963643,
#  ('문화', '공산'): 0.6804749,
#  ('문화', '수도'): 0.7586824,
#  ('문화', '카페'): 0.030738128,
#  ('문화', '안전'): 0.4872134,
#  ('문화', '마곡사'): 0.6260971,
#  ('문화', '축제'): 0.79383904,
#  ('문화', '맛집'): 0.05016831,
#  ('문화', '대전'): 0.5520915,
#  ('문화', '주민'): 0.5366691,
#  ('문화', '금강'): 0.64083695,
#  ('문화', '공원'): 0.7841325,
#  ('문화', '활동'): 0.47647604,
#  ('문화', '관광'): 0.8242284,
#  ('문화', '갑사'): 0.44965923,
#  ('문화', '박물관'): 0.5721938,
#  ('문화', '기자'): 0.62886536,
#  ('문화', '관리'): 0.4980428,
#  ('문화', '복지'): 0.5970389,
#  ('문화', '참여'): 0.72563744,
#  ('문화', '개발'): 0.6579015,
#  ('문화', '진행'): 0.7886097,
#  ('문화', '이용'): 0.6467537,
#  ('문화', '설치'): 0.4749251,
#  ('문화', '농촌'): 0.67170835,
#  ('문화', '공간'): 0.7677709,
#  ('문화', '가능'): 0.55067104,
#  ('문화', '동학사'): -0.04999496,
#  ('문화', '방문'): 0.799773,
#  ('문화', '센터'): 0.7131514,
#  ('문화', '서비스'): 0.6240231,
#  ('문화', '대상'): 0.5006248,
#  ('문화', '조성'): 0.7671027,
#  ('문화', '사회'): 0.60891885,
#  ('문화', '생활'): 0.6410131,
#  ('문화', '도로'): 0.5324503,
#  ('문화', '봉사'): 0.5394518,
#  ('문화', '대회'): 0.74107796,
#  ('문화', '자연'): 0.7111176,
#  ('문화', '사랑'): 0.589778,
#  ('문화', '이건용'): 0.6564672,
#  ('문화', '역사'): 0.7871138,
#  ('문화', '서울'): 0.45190188,
#  ('문화', '행복'): 0.7720647,
#  ('문화', '여행'): 0.6609137,
#  ('문화', '건물'): 0.4747841,
#  ('문화', '시공'): 0.10806506,
#  ('문화', '시대'): 0.5197794,
#  ('문화', '가격'): 0.5992523,
#  ('문화', '농업'): 0.604778,
#  ('문화', '자리'): 0.69358975,
#  ('문화', '발전'): 0.57588863,
#  ('문화', '가족'): 0.8120835,
#  ('문화', '지정'): 0.5986797,
#  ('문화', '시청'): 0.6990724,
#  ('문화', '한국'): 0.8621846,
#  ('문화', '환경'): 0.673385,
#  ('문화', '사용'): 0.7394511,
#  ('문화', '공사'): 0.5900397,
#  ('문화', '학교'): 0.79039365,
#  ('문화', '건강'): 0.59208995,
#  ('문화', '자원'): 0.6846884,
#  ('문화', '반포면'): 0.70504504,
#  ('문화', '신관동'): 0.5474443,
#  ('문화', '아파트'): 0.7301005,
#  ('문화', '평가'): 0.6104967,
#  ('문화', '인테리어'): 0.7168684,
#  ('문화', '제공'): 0.84117347,
#  ('문화', '단체'): 0.68094,
#  ('문화', '예정'): 0.7107945,
#  ('문화', '선정'): 0.5910292,
#  ('문화', '자전거'): 0.75092554,
#  ('문화', '공무원'): 0.57649153,
#  ('문화', '정보'): 0.44736126,
#  ('문화', '기관'): 0.65111005,
#  ('문화', '식당'): 0.7424939,
#  ('문화', '지구'): 0.53365237,
#  ('문화', '의원'): 0.5521172,
#  ('문화', '대표'): 0.7028468,
#  ('문화', '오후'): 0.70463526,
#  ('문화', '건설'): 0.508908,
#  ('문화', '민원'): 0.7155348,
#  ('문화', '프로그램'): 0.75777185,
#  ('시민', '도시'): 0.5807414,
#  ('시민', '체험'): 0.595544,
#  ('시민', '마을'): 0.44132116,
#  ('시민', '사진'): 0.6663404,
#  ('시민', '교육'): 0.61683244,
#  ('시민', '백제'): 0.43063754,
#  ('시민', '토지'): 0.4906437,
#  ('시민', '시장'): 0.6654838,
#  ('시민', '행사'): 0.75212896,
#  ('시민', '행정'): 0.5511832,
#  ('시민', '주택'): 0.47486988,
#  ('시민', '계룡산'): 0.6196721,
#  ('시민', '계획'): 0.53348815,
#  ('시민', '공산'): 0.5134145,
#  ('시민', '수도'): 0.6730866,
#  ('시민', '카페'): 0.09103336,
#  ('시민', '안전'): 0.707658,
#  ('시민', '마곡사'): 0.562496,
#  ('시민', '축제'): 0.70125186,
#  ('시민', '맛집'): 0.032043308,
#  ('시민', '대전'): 0.58400714,
#  ('시민', '주민'): 0.47974214,
#  ('시민', '금강'): 0.5426162,
#  ('시민', '공원'): 0.6977618,
#  ('시민', '활동'): 0.51125365,
#  ('시민', '관광'): 0.58179593,
#  ('시민', '갑사'): 0.37014443,
#  ('시민', '박물관'): 0.3843598,
#  ('시민', '기자'): 0.65777636,
#  ('시민', '관리'): 0.5199323,
#  ('시민', '복지'): 0.4681077,
#  ('시민', '참여'): 0.7270242,
#  ('시민', '개발'): 0.4597811,
#  ('시민', '진행'): 0.6871368,
#  ('시민', '이용'): 0.6025357,
#  ('시민', '설치'): 0.6188454,
#  ('시민', '농촌'): 0.53813446,
#  ('시민', '공간'): 0.51952446,
#  ('시민', '가능'): 0.40800858,
#  ('시민', '동학사'): -0.102277845,
#  ('시민', '방문'): 0.6640031,
#  ('시민', '센터'): 0.54798794,
#  ('시민', '서비스'): 0.47063223,
#  ('시민', '대상'): 0.5264505,
#  ('시민', '조성'): 0.4758102,
#  ('시민', '사회'): 0.48793215,
#  ('시민', '생활'): 0.62529266,
#  ('시민', '도로'): 0.65261614,
#  ('시민', '봉사'): 0.53948313,
#  ('시민', '대회'): 0.58434486,
#  ('시민', '자연'): 0.5943267,
#  ('시민', '사랑'): 0.6226566,
#  ('시민', '이건용'): 0.5673696,
#  ('시민', '역사'): 0.54128605,
#  ('시민', '서울'): 0.5637125,
#  ('시민', '행복'): 0.73290664,
#  ('시민', '여행'): 0.6310375,
#  ('시민', '건물'): 0.45785776,
#  ('시민', '시공'): 0.035923675,
#  ('시민', '시대'): 0.33790922,
#  ('시민', '가격'): 0.6338658,
#  ('시민', '농업'): 0.53332305,
#  ('시민', '자리'): 0.45808867,
#  ('시민', '발전'): 0.6196118,
#  ('시민', '가족'): 0.7177689,
#  ('시민', '지정'): 0.6455141,
#  ('시민', '시청'): 0.5917044,
#  ('시민', '한국'): 0.6857944,
#  ('시민', '환경'): 0.5145757,
#  ('시민', '사용'): 0.6652224,
#  ('시민', '공사'): 0.47404662,
#  ('시민', '학교'): 0.71142715,
#  ('시민', '건강'): 0.67044693,
#  ('시민', '자원'): 0.6394412,
#  ('시민', '반포면'): 0.58129984,
#  ('시민', '신관동'): 0.5533477,
#  ('시민', '아파트'): 0.6861313,
#  ('시민', '평가'): 0.45868996,
#  ('시민', '인테리어'): 0.6423368,
#  ('시민', '제공'): 0.6944487,
#  ('시민', '단체'): 0.6109923,
#  ('시민', '예정'): 0.6577275,
#  ('시민', '선정'): 0.5037157,
#  ('시민', '자전거'): 0.67936563,
#  ('시민', '공무원'): 0.6174327,
#  ('시민', '정보'): 0.41175902,
#  ('시민', '기관'): 0.6799431,
#  ('시민', '식당'): 0.744431,
#  ('시민', '지구'): 0.44637036,
#  ('시민', '의원'): 0.52632314,
#  ('시민', '대표'): 0.602332,
#  ('시민', '오후'): 0.66905206,
#  ('시민', '건설'): 0.5763961,
#  ('시민', '민원'): 0.67461437,
#  ('시민', '프로그램'): 0.7069133,
#  ('도시', '체험'): 0.55206376,
#  ('도시', '마을'): 0.40441796,
#  ('도시', '사진'): 0.46966973,
#  ('도시', '교육'): 0.48060554,
#  ('도시', '백제'): 0.5260965,
#  ('도시', '토지'): 0.8344476,
#  ('도시', '시장'): 0.55708367,
#  ('도시', '행사'): 0.48806715,
#  ('도시', '행정'): 0.68771183,
#  ('도시', '주택'): 0.55115837,
#  ('도시', '계룡산'): 0.5930242,
#  ('도시', '계획'): 0.7642552,
#  ('도시', '공산'): 0.7161023,
#  ('도시', '수도'): 0.7608588,
#  ('도시', '카페'): 0.017006025,
#  ('도시', '안전'): 0.4493903,
#  ('도시', '마곡사'): 0.5029975,
#  ('도시', '축제'): 0.6587547,
#  ('도시', '맛집'): 0.11768163,
#  ('도시', '대전'): 0.7745169,
#  ('도시', '주민'): 0.60783523,
#  ('도시', '금강'): 0.6190563,
#  ('도시', '공원'): 0.667297,
#  ('도시', '활동'): 0.44148052,
#  ('도시', '관광'): 0.72198725,
#  ('도시', '갑사'): 0.29995257,
#  ('도시', '박물관'): 0.50373656,
#  ('도시', '기자'): 0.6018541,
#  ('도시', '관리'): 0.7881685,
#  ('도시', '복지'): 0.5711593,
#  ('도시', '참여'): 0.5618502,
#  ('도시', '개발'): 0.8607405,
#  ('도시', '진행'): 0.6527406,
#  ('도시', '이용'): 0.67325526,
#  ('도시', '설치'): 0.6972875,
#  ('도시', '농촌'): 0.56320477,
#  ('도시', '공간'): 0.6669538,
#  ('도시', '가능'): 0.7970835,
#  ('도시', '동학사'): 0.0101099,
#  ('도시', '방문'): 0.7165872,
#  ('도시', '센터'): 0.65448886,
#  ('도시', '서비스'): 0.6482675,
#  ('도시', '대상'): 0.47612214,
#  ('도시', '조성'): 0.69418806,
#  ('도시', '사회'): 0.52901053,
#  ('도시', '생활'): 0.5974748,
#  ('도시', '도로'): 0.7286632,
#  ('도시', '봉사'): 0.43253016,
#  ('도시', '대회'): 0.51306844,
#  ('도시', '자연'): 0.6339268,
#  ('도시', '사랑'): 0.390878,
#  ('도시', '이건용'): 0.6388867,
#  ('도시', '역사'): 0.71541286,
#  ('도시', '서울'): 0.4661274,
#  ('도시', '행복'): 0.77556336,
#  ('도시', '여행'): 0.67081505,
#  ('도시', '건물'): 0.46208766,
#  ('도시', '시공'): 0.077446446,
#  ('도시', '시대'): 0.4009291,
#  ('도시', '가격'): 0.7280756,
#  ('도시', '농업'): 0.50888336,
#  ('도시', '자리'): 0.5288511,
#  ('도시', '발전'): 0.5823483,
#  ('도시', '가족'): 0.60285044,
#  ('도시', '지정'): 0.7046514,
#  ('도시', '시청'): 0.5946159,
#  ('도시', '한국'): 0.63851535,
#  ('도시', '환경'): 0.7998433,
#  ('도시', '사용'): 0.71132493,
#  ('도시', '공사'): 0.6708166,
#  ('도시', '학교'): 0.6218633,
#  ('도시', '건강'): 0.4768572,
#  ('도시', '자원'): 0.428739,
#  ('도시', '반포면'): 0.7484884,
#  ('도시', '신관동'): 0.552972,
#  ('도시', '아파트'): 0.8199759,
#  ('도시', '평가'): 0.7055083,
#  ('도시', '인테리어'): 0.68297017,
#  ('도시', '제공'): 0.67114645,
#  ('도시', '단체'): 0.527059,
#  ('도시', '예정'): 0.5643072,
#  ('도시', '선정'): 0.54942334,
#  ('도시', '자전거'): 0.7771556,
#  ('도시', '공무원'): 0.53580785,
#  ('도시', '정보'): 0.46766454,
#  ('도시', '기관'): 0.5353594,
#  ('도시', '식당'): 0.63065445,
#  ('도시', '지구'): 0.7069692,
#  ('도시', '의원'): 0.66498864,
#  ('도시', '대표'): 0.626427,
#  ('도시', '오후'): 0.48608652,
#  ('도시', '건설'): 0.7530844,
#  ('도시', '민원'): 0.7377516,
#  ('도시', '프로그램'): 0.68780035,
#  ('체험', '마을'): 0.55496746,
#  ('체험', '사진'): 0.63522214,
#  ('체험', '교육'): 0.73427474,
#  ('체험', '백제'): 0.587758,
#  ('체험', '토지'): 0.5382324,
#  ('체험', '시장'): 0.5730725,
#  ('체험', '행사'): 0.8462257,
#  ('체험', '행정'): 0.5723967,
#  ('체험', '주택'): 0.48599657,
#  ('체험', '계룡산'): 0.6626356,
#  ('체험', '계획'): 0.6011389,
#  ('체험', '공산'): 0.5586182,
#  ('체험', '수도'): 0.65541637,
#  ('체험', '카페'): -0.0062774657,
#  ('체험', '안전'): 0.57768303,
#  ('체험', '마곡사'): 0.57546264,
#  ('체험', '축제'): 0.6386089,
#  ('체험', '맛집'): 0.10003323,
#  ('체험', '대전'): 0.41032097,
#  ('체험', '주민'): 0.593663,
#  ('체험', '금강'): 0.6046104,
#  ('체험', '공원'): 0.74454594,
#  ('체험', '활동'): 0.53490424,
#  ('체험', '관광'): 0.66671443,
#  ('체험', '갑사'): 0.36437392,
#  ('체험', '박물관'): 0.594643,
#  ('체험', '기자'): 0.5895613,
#  ('체험', '관리'): 0.52345985,
#  ('체험', '복지'): 0.79143447,
#  ('체험', '참여'): 0.76630634,
#  ('체험', '개발'): 0.5375465,
#  ('체험', '진행'): 0.83145607,
#  ('체험', '이용'): 0.63169765,
#  ('체험', '설치'): 0.44460726,
#  ('체험', '농촌'): 0.75585985,
#  ('체험', '공간'): 0.8197723,
#  ('체험', '가능'): 0.4811428,
#  ('체험', '동학사'): -0.025234986,
#  ('체험', '방문'): 0.7807064,
#  ('체험', '센터'): 0.7039762,
#  ('체험', '서비스'): 0.75830925,
#  ('체험', '대상'): 0.5987694,
#  ('체험', '조성'): 0.6830831,
#  ('체험', '사회'): 0.83240587,
#  ('체험', '생활'): 0.756222,
#  ('체험', '도로'): 0.47070378,
#  ('체험', '봉사'): 0.67409396,
#  ('체험', '대회'): 0.69157714,
#  ('체험', '자연'): 0.7553896,
#  ('체험', '사랑'): 0.6943778,
#  ('체험', '이건용'): 0.5923344,
#  ('체험', '역사'): 0.61315984,
#  ('체험', '서울'): 0.48103243,
#  ('체험', '행복'): 0.7101121,
#  ('체험', '여행'): 0.61081064,
#  ('체험', '건물'): 0.46073815,
#  ('체험', '시공'): 0.06811725,
#  ('체험', '시대'): 0.41837847,
#  ('체험', '가격'): 0.55297875,
#  ('체험', '농업'): 0.60901016,
#  ('체험', '자리'): 0.5593827,
#  ('체험', '발전'): 0.52684766,
#  ('체험', '가족'): 0.85742944,
#  ('체험', '지정'): 0.61048734,
#  ('체험', '시청'): 0.5978641,
#  ('체험', '한국'): 0.8606764,
#  ('체험', '환경'): 0.71667427,
#  ('체험', '사용'): 0.7564953,
#  ('체험', '공사'): 0.4928944,
#  ('체험', '학교'): 0.83364666,
#  ('체험', '건강'): 0.67218727,
#  ('체험', '자원'): 0.8165603,
#  ('체험', '반포면'): 0.82549614,
#  ('체험', '신관동'): 0.5094979,
#  ('체험', '아파트'): 0.683893,
#  ('체험', '평가'): 0.58248687,
#  ('체험', '인테리어'): 0.6982394,
#  ('체험', '제공'): 0.8915276,
#  ('체험', '단체'): 0.68501747,
#  ('체험', '예정'): 0.66643184,
#  ('체험', '선정'): 0.65344715,
#  ('체험', '자전거'): 0.72990245,
#  ('체험', '공무원'): 0.7527721,
#  ('체험', '정보'): 0.5363029,
#  ('체험', '기관'): 0.6251043,
#  ('체험', '식당'): 0.7943177,
#  ('체험', '지구'): 0.48037097,
#  ('체험', '의원'): 0.5406453,
#  ('체험', '대표'): 0.580255,
#  ('체험', '오후'): 0.7162182,
#  ('체험', '건설'): 0.39580908,
#  ('체험', '민원'): 0.6939231,
#  ('체험', '프로그램'): 0.7775762,
#  ('마을', '사진'): 0.6885527,
#  ('마을', '교육'): 0.5033496,
#  ('마을', '백제'): 0.39848328,
#  ('마을', '토지'): 0.43628797,
#  ('마을', '시장'): 0.5576837,
#  ('마을', '행사'): 0.547422,
#  ('마을', '행정'): 0.67079675,
#  ('마을', '주택'): 0.68640083,
#  ('마을', '계룡산'): 0.6511504,
#  ('마을', '계획'): 0.45944226,
#  ('마을', '공산'): 0.40029696,
#  ('마을', '수도'): 0.64314145,
#  ('마을', '카페'): -0.0023426868,
#  ('마을', '안전'): 0.5273851,
#  ('마을', '마곡사'): 0.61799246,
#  ('마을', '축제'): 0.5184912,
#  ('마을', '맛집'): 0.094384566,
#  ('마을', '대전'): 0.64221066,
#  ('마을', '주민'): 0.7836247,
#  ('마을', '금강'): 0.3881263,
#  ('마을', '공원'): 0.49014512,
#  ('마을', '활동'): 0.6052124,
#  ('마을', '관광'): 0.41761142,
#  ('마을', '갑사'): 0.40010154,
#  ('마을', '박물관'): 0.46023932,
#  ('마을', '기자'): 0.5148517,
#  ('마을', '관리'): 0.3908634,
#  ('마을', '복지'): 0.66096723,
#  ('마을', '참여'): 0.5569764,
#  ('마을', '개발'): 0.3279788,
#  ('마을', '진행'): 0.56626797,
#  ('마을', '이용'): 0.6629146,
#  ('마을', '설치'): 0.4683902,
#  ('마을', '농촌'): 0.7045212,
#  ('마을', '공간'): 0.52700925,
#  ('마을', '가능'): 0.33472472,
#  ('마을', '동학사'): -0.11379727,
#  ('마을', '방문'): 0.6537863,
#  ('마을', '센터'): 0.6481394,
#  ('마을', '서비스'): 0.73707616,
#  ('마을', '대상'): 0.5130886,
#  ('마을', '조성'): 0.48995596,
#  ('마을', '사회'): 0.63973,
#  ('마을', '생활'): 0.6009917,
#  ('마을', '도로'): 0.62334645,
#  ('마을', '봉사'): 0.8277218,
#  ('마을', '대회'): 0.4952858,
#  ('마을', '자연'): 0.34426454,
#  ('마을', '사랑'): 0.78826076,
#  ('마을', '이건용'): 0.5481206,
#  ('마을', '역사'): 0.48207125,
#  ('마을', '서울'): 0.80620253,
#  ('마을', '행복'): 0.64484704,
#  ('마을', '여행'): 0.6752024,
#  ('마을', '건물'): 0.65911454,
#  ('마을', '시공'): 0.044182748,
#  ('마을', '시대'): 0.42498556,
#  ('마을', '가격'): 0.57668626,
#  ('마을', '농업'): 0.54691744,
#  ('마을', '자리'): 0.6077845,
#  ('마을', '발전'): 0.51949245,
#  ('마을', '가족'): 0.64078075,
#  ('마을', '지정'): 0.57463115,
#  ('마을', '시청'): 0.61145824,
#  ('마을', '한국'): 0.55220956,
#  ('마을', '환경'): 0.44738668,
#  ('마을', '사용'): 0.65298814,
#  ('마을', '공사'): 0.42204088,
#  ('마을', '학교'): 0.80017036,
#  ('마을', '건강'): 0.576379,
#  ('마을', '자원'): 0.68798304,
#  ('마을', '반포면'): 0.6485621,
#  ('마을', '신관동'): 0.5741827,
#  ('마을', '아파트'): 0.65485245,
#  ('마을', '평가'): 0.43401587,
#  ('마을', '인테리어'): 0.66583365,
#  ('마을', '제공'): 0.5995192,
#  ('마을', '단체'): 0.6302742,
#  ('마을', '예정'): 0.47429436,
#  ('마을', '선정'): 0.49410456,
#  ('마을', '자전거'): 0.71538883,
#  ('마을', '공무원'): 0.6684213,
#  ('마을', '정보'): 0.5057695,
#  ('마을', '기관'): 0.5417343,
#  ('마을', '식당'): 0.73518825,
#  ('마을', '지구'): 0.28417432,
#  ('마을', '의원'): 0.46926686,
#  ('마을', '대표'): 0.5620426,
#  ('마을', '오후'): 0.65894353,
#  ('마을', '건설'): 0.50168335,
#  ('마을', '민원'): 0.7536247,
#  ('마을', '프로그램'): 0.7047591,
#  ('사진', '교육'): 0.61707217,
#  ('사진', '백제'): 0.6122236,
#  ('사진', '토지'): 0.4461766,
#  ('사진', '시장'): 0.5910531,
#  ('사진', '행사'): 0.7582205,
#  ('사진', '행정'): 0.50109446,
#  ('사진', '주택'): 0.57745814,
#  ('사진', '계룡산'): 0.866756,
#  ('사진', '계획'): 0.503367,
#  ('사진', '공산'): 0.7277361,
#  ('사진', '수도'): 0.790496,
#  ('사진', '카페'): 0.016934223,
#  ('사진', '안전'): 0.6342539,
#  ('사진', '마곡사'): 0.63881403,
#  ('사진', '축제'): 0.62170553,
#  ('사진', '맛집'): -0.00081077724,
#  ('사진', '대전'): 0.7363466,
#  ('사진', '주민'): 0.44995746,
#  ('사진', '금강'): 0.77566236,
#  ('사진', '공원'): 0.74790907,
#  ('사진', '활동'): 0.4977593,
#  ('사진', '관광'): 0.5643593,
#  ('사진', '갑사'): 0.55252415,
#  ('사진', '박물관'): 0.5343426,
#  ('사진', '기자'): 0.58098614,
#  ('사진', '관리'): 0.41302857,
#  ('사진', '복지'): 0.50542337,
#  ('사진', '참여'): 0.5790398,
#  ('사진', '개발'): 0.45004272,
#  ('사진', '진행'): 0.6854837,
#  ('사진', '이용'): 0.6896365,
#  ('사진', '설치'): 0.6308011,
#  ('사진', '농촌'): 0.58768564,
#  ('사진', '공간'): 0.51207334,
#  ('사진', '가능'): 0.42951965,
#  ('사진', '동학사'): -0.15266693,
#  ('사진', '방문'): 0.59730065,
#  ('사진', '센터'): 0.502162,
#  ('사진', '서비스'): 0.47841707,
#  ('사진', '대상'): 0.5507646,
#  ('사진', '조성'): 0.45548257,
#  ('사진', '사회'): 0.56487757,
#  ('사진', '생활'): 0.5092824,
#  ('사진', '도로'): 0.74858844,
#  ('사진', '봉사'): 0.6182005,
#  ('사진', '대회'): 0.6083137,
#  ('사진', '자연'): 0.6242903,
#  ('사진', '사랑'): 0.84189,
#  ('사진', '이건용'): 0.5706656,
#  ('사진', '역사'): 0.67357486,
#  ('사진', '서울'): 0.7942309,
#  ('사진', '행복'): 0.6679144,
#  ('사진', '여행'): 0.8346703,
#  ('사진', '건물'): 0.85681117,
#  ('사진', '시공'): 0.047694724,
#  ('사진', '시대'): 0.4637274,
#  ('사진', '가격'): 0.5164251,
#  ('사진', '농업'): 0.64446986,
#  ('사진', '자리'): 0.7021704,
#  ('사진', '발전'): 0.6754968,
#  ('사진', '가족'): 0.73730695,
#  ('사진', '지정'): 0.622953,
#  ('사진', '시청'): 0.62242216,
#  ('사진', '한국'): 0.77785534,
#  ('사진', '환경'): 0.4882218,
#  ('사진', '사용'): 0.6975072,
#  ('사진', '공사'): 0.47759122,
#  ('사진', '학교'): 0.83344114,
#  ('사진', '건강'): 0.6026204,
#  ('사진', '자원'): 0.7002251,
#  ('사진', '반포면'): 0.5297709,
#  ('사진', '신관동'): 0.83390856,
#  ('사진', '아파트'): 0.64770573,
#  ('사진', '평가'): 0.377125,
#  ('사진', '인테리어'): 0.68420684,
#  ('사진', '제공'): 0.6534902,
#  ('사진', '단체'): 0.59129757,
#  ('사진', '예정'): 0.5656947,
#  ('사진', '선정'): 0.46524963,
#  ('사진', '자전거'): 0.8134172,
#  ('사진', '공무원'): 0.6643385,
#  ('사진', '정보'): 0.44047895,
#  ('사진', '기관'): 0.56565183,
#  ('사진', '식당'): 0.84105307,
#  ('사진', '지구'): 0.44026104,
#  ('사진', '의원'): 0.56244034,
#  ('사진', '대표'): 0.7378511,
#  ('사진', '오후'): 0.6632674,
#  ('사진', '건설'): 0.43929854,
#  ('사진', '민원'): 0.7039009,
#  ('사진', '프로그램'): 0.7230866,
#  ('교육', '백제'): 0.41486406,
#  ('교육', '토지'): 0.603752,
#  ('교육', '시장'): 0.6050176,
#  ('교육', '행사'): 0.68073136,
#  ('교육', '행정'): 0.5994424,
#  ('교육', '주택'): 0.6872325,
#  ('교육', '계룡산'): 0.5988994,
#  ('교육', '계획'): 0.65051866,
#  ('교육', '공산'): 0.50368303,
#  ('교육', '수도'): 0.6251292,
#  ('교육', '카페'): 0.012742655,
#  ('교육', '안전'): 0.7702819,
#  ('교육', '마곡사'): 0.44400752,
#  ('교육', '축제'): 0.45303488,
#  ('교육', '맛집'): 0.08739944,
#  ('교육', '대전'): 0.38951445,
#  ('교육', '주민'): 0.552413,
#  ('교육', '금강'): 0.5343882,
#  ('교육', '공원'): 0.544437,
#  ('교육', '활동'): 0.5976745,
#  ('교육', '관광'): 0.5281881,
#  ('교육', '갑사'): 0.33924577,
#  ('교육', '박물관'): 0.3784861,
#  ('교육', '기자'): 0.5898061,
#  ('교육', '관리'): 0.6658795,
#  ('교육', '복지'): 0.67447156,
#  ('교육', '참여'): 0.65057164,
#  ('교육', '개발'): 0.48430327,
#  ('교육', '진행'): 0.6727844,
#  ('교육', '이용'): 0.6635378,
#  ('교육', '설치'): 0.73538035,
#  ('교육', '농촌'): 0.60938257,
#  ('교육', '공간'): 0.584913,
#  ('교육', '가능'): 0.5081793,
#  ('교육', '동학사'): -0.0006957275,
#  ('교육', '방문'): 0.58615744,
#  ('교육', '센터'): 0.5081025,
#  ('교육', '서비스'): 0.6480078,
#  ('교육', '대상'): 0.8243732,
#  ('교육', '조성'): 0.42482463,
#  ('교육', '사회'): 0.6386828,
#  ('교육', '생활'): 0.75369203,
#  ('교육', '도로'): 0.56571436,
#  ('교육', '봉사'): 0.6485648,
#  ('교육', '대회'): 0.59367925,
#  ('교육', '자연'): 0.6134483,
#  ('교육', '사랑'): 0.6291713,
#  ('교육', '이건용'): 0.4873863,
#  ('교육', '역사'): 0.44809428,
#  ('교육', '서울'): 0.52069205,
#  ('교육', '행복'): 0.6602294,
#  ('교육', '여행'): 0.55383044,
#  ('교육', '건물'): 0.46797928,
#  ('교육', '시공'): 0.016899984,
#  ('교육', '시대'): 0.49331766,
#  ('교육', '가격'): 0.6349529,
#  ('교육', '농업'): 0.6446074,
#  ('교육', '자리'): 0.35006908,
#  ('교육', '발전'): 0.5979321,
#  ('교육', '가족'): 0.6271509,
#  ('교육', '지정'): 0.74016374,
#  ('교육', '시청'): 0.5141659,
#  ('교육', '한국'): 0.6657795,
#  ('교육', '환경'): 0.68972635,
#  ('교육', '사용'): 0.7494629,
#  ('교육', '공사'): 0.4573771,
#  ('교육', '학교'): 0.72289115,
#  ('교육', '건강'): 0.8894204,
#  ('교육', '자원'): 0.7967668,
#  ('교육', '반포면'): 0.70331,
#  ('교육', '신관동'): 0.4952309,
#  ('교육', '아파트'): 0.7340871,
#  ('교육', '평가'): 0.63375425,
#  ('교육', '인테리어'): 0.68438995,
#  ('교육', '제공'): 0.7072634,
#  ('교육', '단체'): 0.7076734,
#  ('교육', '예정'): 0.65463096,
#  ('교육', '선정'): 0.77694076,
#  ('교육', '자전거'): 0.6951263,
#  ('교육', '공무원'): 0.7537858,
#  ('교육', '정보'): 0.83503455,
#  ('교육', '기관'): 0.6925587,
#  ('교육', '식당'): 0.7980065,
#  ('교육', '지구'): 0.5944272,
#  ('교육', '의원'): 0.46139312,
#  ('교육', '대표'): 0.62834585,
#  ('교육', '오후'): 0.6628745,
#  ('교육', '건설'): 0.43709788,
#  ('교육', '민원'): 0.7092605,
#  ('교육', '프로그램'): 0.800423,
#  ('백제', '토지'): 0.52890503,
#  ('백제', '시장'): 0.42681167,
#  ('백제', '행사'): 0.5809488,
#  ('백제', '행정'): 0.42586803,
#  ('백제', '주택'): 0.45629647,
#  ('백제', '계룡산'): 0.8320169,
#  ('백제', '계획'): 0.3517497,
#  ('백제', '공산'): 0.79688936,
#  ('백제', '수도'): 0.6832315,
#  ('백제', '카페'): -0.028350549,
#  ('백제', '안전'): 0.4527121,
#  ('백제', '마곡사'): 0.6386715,
#  ('백제', '축제'): 0.65079695,
#  ('백제', '맛집'): 0.014785978,
#  ('백제', '대전'): 0.5046744,
#  ('백제', '주민'): 0.34743842,
#  ('백제', '금강'): 0.69009054,
#  ('백제', '공원'): 0.6788178,
#  ('백제', '활동'): 0.32331675,
#  ('백제', '관광'): 0.73719007,
#  ('백제', '갑사'): 0.6843188,
#  ('백제', '박물관'): 0.63889205,
#  ('백제', '기자'): 0.49618104,
#  ('백제', '관리'): 0.40543437,
#  ('백제', '복지'): 0.426893,
#  ('백제', '참여'): 0.47760808,
#  ('백제', '개발'): 0.55774355,
#  ('백제', '진행'): 0.46013513,
#  ('백제', '이용'): 0.67712164,
#  ('백제', '설치'): 0.43371204,
#  ('백제', '농촌'): 0.42872003,
#  ('백제', '공간'): 0.6339426,
#  ('백제', '가능'): 0.49086437,
#  ('백제', '동학사'): -0.05817607,
#  ('백제', '방문'): 0.49763313,
#  ('백제', '센터'): 0.48468915,
#  ('백제', '서비스'): 0.45595026,
#  ('백제', '대상'): 0.33516958,
#  ('백제', '조성'): 0.5843193,
#  ('백제', '사회'): 0.43475935,
#  ('백제', '생활'): 0.42296192,
#  ('백제', '도로'): 0.54470766,
#  ('백제', '봉사'): 0.42858592,
#  ('백제', '대회'): 0.46904817,
#  ('백제', '자연'): 0.5486416,
#  ('백제', '사랑'): 0.52651477,
#  ('백제', '이건용'): 0.56532663,
#  ('백제', '역사'): 0.8062866,
#  ('백제', '서울'): 0.37116563,
#  ('백제', '행복'): 0.51705575,
#  ('백제', '여행'): 0.6739363,
#  ('백제', '건물'): 0.6443321,
#  ('백제', '시공'): 0.10349442,
#  ('백제', '시대'): 0.80461735,
#  ('백제', '가격'): 0.48116255,
#  ...}

# %% [markdown]
# ### 저장

# %%
# 딕셔너리를 리스트로 변환
count_list = []

# count_list에 단어1, 단어2, 코사인유사도 형태로 저장
for row in count_dict:
    count_list.append([row[0], row[1], count_dict[row]])

# %%
# DataFrame 형식으로 만든다.
sim_df = pd.DataFrame(count_list, columns=['word1', 'word2', 'cos_sim'])
sim_df = sim_df.sort_values(by=['cos_sim'], ascending=False)
sim_df = sim_df.reset_index(drop=True)

# 단어쌍 결과를 csv로 저장
sim_df.to_csv('./dataset/gyeongju/graph_cosine_similarity.csv', encoding='euc-kr')
sim_df.head()
# Out:
#   word1 word2   cos_sim
# 0   아파트    민원  0.963640
# 1    사용   자전거  0.952740
# 2    복지    사회  0.951807
# 3    사용    식당  0.951608
# 4   자전거    식당  0.947989

# %% [markdown]
# # Graph Clustering

# %%
import operator

# 그래프
import networkx as nx
import community as community_louvain

# 시각화
import matplotlib.cm as cm
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# 폰트설정, 한글깨짐방지
fm._rebuild()
font_fname = 'C:/Windows/Fonts/malgun.ttf'
fontprop = fm.FontProperties(fname=font_fname).get_name()

# %%
cossim_df = pd.read_csv('./dataset/gyeongju/graph_cosine_similarity.csv', encoding='euc-kr')
org_cossim_df = cossim_df.copy()

cossim_df['cos_sim'] = org_cossim_df['cos_sim']
cossim_df = cossim_df.dropna()
cossim_df.head()
# Out:
#    Unnamed: 0 word1 word2   cos_sim
# 0           0    마을    양동  0.981926
# 1           1    주문   떡갈비  0.944027
# 2           2    카페    가격  0.939797
# 3           3    가을    단풍  0.938057
# 4           4    야경    쌈밥  0.936121

# %%
# Thershold 설정
threshold = 0.64

"""
차수(Degree) 계산
"""
# 그래프 생성
G = nx.Graph()

# 거리가 threshold 초과 단어쌍에 대해서만 edge 생성
for idx in tqdm(range((len(np.where(cossim_df['cos_sim'] >= threshold)[0])))):
    G.add_edge(cossim_df['word1'][idx], cossim_df['word2'][idx], weight=cossim_df['cos_sim'][idx])

# Degree Centrality 계산
dgr = nx.degree_centrality(G)

# 내림차순 정렬
sorted_dgr = sorted(dgr.items(), key=operator.itemgetter(1), reverse=True)

# 노드생성, degree에 따라 노드 크기 결정
for idx in range(len(sorted_dgr)):
    G.add_node(sorted_dgr[idx][0], nodesize=sorted_dgr[idx][1])

# 노드 제거
# G.remove_node('세계')
# G.remove_node('건물')
"""
그래프 클러스터링 (louvain)
"""

# 클러스터(파티션) 계산
partition = community_louvain.best_partition(G, random_state=14)

# 레이아웃 설정
pos = nx.spring_layout(G)

# 클러스터(파티션)에 따른 색상 결정
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)

"""
그래프 시각화
"""
# 그래프 크기 설정
fig = plt.figure(figsize=(18,10))

# 노드 및 엣지크기 설정
sizes = [G.nodes[node]['nodesize'] * 200 for node in G] # 노드사이즈
edge_wts = [0.3 * edge[2] for edge in G.edges(data = 'weight')] # 엣지사이즈

# 그래프 시각화
im = nx.draw_networkx_nodes(G, pos, cmap=cmap, node_size=sizes, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5, width=edge_wts)
nx.draw_networkx_labels(G, pos, font_size=10, font_color="BLACK", font_family=fontprop)
plt.colorbar(im)
plt.show(block=False)

# 커뮤니티 텍스트 출력
count = 0    
node_count = 0
nodes_list = []
strdata = ''
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]
    node_count = node_count + len(list_nodes)
    nodes_list.append(list_nodes)
    strdata = strdata + '\n커뮤니티' + str(int(count)) + '\n'

    for s in list_nodes:        
        strdata = strdata + s + " "

    print('커뮤니티', int(count), '\n',list_nodes, '\n')

print('노드 수 : ', node_count)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 1343/1343 [00:00<00:00, 58541.19it/s]
# 커뮤니티 1
#  ['가을', '단풍', '이야기', '불국사', '모습', '나무', '사진', '소리', '친구', '공간', '바람', '산책', '생각', '기억', '풍경', '날씨', '아침', '마음', '입구', '시작', '가족', '바다', '사람', '석굴암']
#
# 커뮤니티 2
#  ['주문', '떡갈비', '카페', '가격', '메뉴', '커피', '맛집', '반찬', '엄마', '고기', '추천', '정식', '식사', '가지', '분위기', '저녁', '준비', '점심', '식당', '음식', '가능', '기분', '순두부', '방문', '저희', '유명', '이름', '건물', '주차장', '황남빵']
#
# 커뮤니티 3
#  ['마을', '양동', '한옥', '신라', '시대', '체험', '역사', '문화', '하늘', '자리', '위치', '세계']
#
# 커뮤니티 4
#  ['야경', '쌈밥', '보문', '단지', '한우', '대릉원', '천마총', '경주', '여행', '출발', '주말', '박물관', '도착', '버스', '하루', '첨성대', '안압지', '연꽃', '벚꽃', '구경', '숙소', '입장료', '거리', '펜션', '공원', '이용', '시간', '시내', '코스', '남산', '자전거', '호텔']
#
# 노드 수 :  98
